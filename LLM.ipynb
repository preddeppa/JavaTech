# %% [markdown]
# <a href="https://colab.research.google.com/github/preddeppa/JavaTech/blob/main/LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
from matplotlib import pyplot as plt
image=Image.open("/content/rrr2-1.jpg")
plt.imshow(image)
